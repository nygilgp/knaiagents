# %% [markdown]
# # Langcahin
#
# * Setup langcahin
# * Basic and common components: promp templates, models and output parser
# * Build simple app with Langchain
# * Trace app with LangSmith
# * Serve your app (api) with LangServe
